# %% [markdown]
# # Project - Regression Modeling with the Ames Housing Dataset
#
# ## Introduction
#
# In this lab, you'll apply the regression analysis and diagnostics techniques covered in this section to the "Ames Housing" dataset. You performed a detailed EDA for this dataset earlier on, and hopefully, you more or less recall how this data is structured! In this lab, you'll use some of the features in this dataset to create a linear model to predict the house price!
#
# ## Objectives
# You will be able to:
# * Perform a linear regression using statsmodels
# * Determine if a particular set of data exhibits the assumptions of linear regression
# * Evaluate a linear regression model by using statistical performance metrics pertaining to overall model and specific parameters
# * Use the coefficient of determination to determine model performance
# * Interpret the parameters of a simple linear regression model in relation to what they signify for specific data
#
#
# ## Let's get started
#
# ### Import necessary libraries and load 'ames.csv' as a pandas dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')
ames = pd.read_csv('ames.csv')

subset = ['YrSold', 'MoSold', 'Fireplaces', 'TotRmsAbvGrd', 'GrLivArea',
          'FullBath', 'YearRemodAdd', 'YearBuilt', 'OverallCond', 'OverallQual', 'LotArea', 'SalePrice']

data = ames.loc[:, subset]

# %% [markdown]
# The columns in the Ames housing data represent the dependent and independent variables. We have taken a subset of all columns available to focus on feature interpretation rather than preprocessing steps. The dependent variable here is the sale price of a house `SalePrice`. The description of the other variables is available on [KAGGLE](https://www.kaggle.com/c/house-prices-advanced-regression-techniques).
#
# ### Inspect the columns of the dataset and comment on type of variables present

# %%
data.dtypes
# Out:
# YrSold          int64
# MoSold          int64
# Fireplaces      int64
# TotRmsAbvGrd    int64
# GrLivArea       int64
# FullBath        int64
# YearRemodAdd    int64
# YearBuilt       int64
# OverallCond     int64
# OverallQual     int64
# LotArea         int64
# SalePrice       int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# YrSold          0
# MoSold          0
# Fireplaces      0
# TotRmsAbvGrd    0
# GrLivArea       0
# FullBath        0
# YearRemodAdd    0
# YearBuilt       0
# OverallCond     0
# OverallQual     0
# LotArea         0
# SalePrice       0
# dtype: int64

# %%
data['OverallQual'].value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
data['GrLivArea'].nunique()
# Out:
# 861

# %%
# Your code here
data.head()
# Out:
#    YrSold  MoSold  Fireplaces  TotRmsAbvGrd  GrLivArea  FullBath  \
# 0    2008       2           0             8       1710         2
# 1    2007       5           1             6       1262         2
# 2    2008       9           1             6       1786         2
# 3    2006       2           1             7       1717         1
# 4    2008      12           1             9       2198         2
#
#    YearRemodAdd  YearBuilt  OverallCond  OverallQual  LotArea  SalePrice
# 0          2003       2003            5            7     8450     208500
# 1          1976       1976            8            6     9600     181500
# 2          2002       2001            5            7    11250     223500
# 3          1970       1915            5            7     9550     140000
# 4          2000       2000            5            8    14260     250000

# %%
# Record your observations here 
# All the values are integers.
# There are no null values present. 
# Mix of Categorical Features and Continuous Features.

# %% [markdown]
# ### Create histograms for all variables in the dataset and comment on their shape (uniform or not?)

# %%
data.hist(figsize = (20, 15));

# %%
# MoSold Hist., TotRmsAbvGrd Hist., and OverallQual Hist. seem to follow a uniform distribution.

# %%
# You observations here

# %% [markdown]
# ### Check the linearity assumption for all chosen features with target variable using scatter plots

# %%
import seaborn as sns

# %%
for col in data.columns:
    sns.regplot(col, 'SalePrice', data = data)
    plt.show()

# %%
sns.boxplot( x = 'YrSold', y = 'SalePrice', data = data)
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='SalePrice'>

# %%
sns.boxplot( x = 'OverallQual', y = 'SalePrice', data = data)
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %% [markdown]
# Clearly, your data needs a lot of preprocessing to improve the results. This key behind a Kaggle competition is to process the data in such a way that you can identify the relationships and make predictions in the best possible way. For now, we'll use the dataset untouched and just move on with the regression. The assumptions are not _exactly_ all fulfilled, but they still hold to a level that we can move on.
#
# ### Let's do Regression
#
# Now, let's perform a number of simple regression experiments between the chosen independent variables and the dependent variable (price). You'll do this in a loop and in every iteration, you should pick one of the independent variables. Perform the following steps:
#
# * Run a simple OLS regression between independent and dependent variables
# * Plot the residuals using `sm.graphics.plot_regress_exog()`
# * Plot a Q-Q plot for regression residuals normality test
# * Store following values in array for each iteration:
#     * Independent Variable
#     * r_squared'
#     * intercept'
#     * 'slope'
#     * 'p-value'
#     * 'normality (JB)'
# * Comment on each output

# %%
data.head()
# Out:
#    YrSold  MoSold  Fireplaces  TotRmsAbvGrd  GrLivArea  FullBath  \
# 0    2008       2           0             8       1710         2
# 1    2007       5           1             6       1262         2
# 2    2008       9           1             6       1786         2
# 3    2006       2           1             7       1717         1
# 4    2008      12           1             9       2198         2
#
#    YearRemodAdd  YearBuilt  OverallCond  OverallQual  LotArea  SalePrice
# 0          2003       2003            5            7     8450     208500
# 1          1976       1976            8            6     9600     181500
# 2          2002       2001            5            7    11250     223500
# 3          1970       1915            5            7     9550     140000
# 4          2000       2000            5            8    14260     250000

# %%
# Run a simple OLS regression between independent and dependent variables
import statsmodels.formula.api as smf
import statsmodels.api as sm
import scipy.stats as stats
import statsmodels.stats.api as sms
# from statsmodels.formula.api import ols

# %%
print('YrSold')
formula = 'SalePrice ~ YrSold'
model = smf.ols(formula = formula, data = data).fit()
model.summary()
# Plot the residuals using sm.graphics.plot_regress_exog()
sm.graphics.plot_regress_exog(model, 'YrSold')
# QQ Plot on residuals to see if they are normally distributed.
sm.graphics.qqplot(model.resid, stats.norm, line = '45', fit = True)
sns.distplot(model.resid)
results_dict = {'Var': 'YrSold', 'R Squared': model.rsquared, 'Intercept': model.params[0], 
                'Slope': model.params[1], 'P-value': model.pvalues[1], 'JB P-value': sms.jarque_bera(model.resid)[1]}
display(pd.DataFrame(results_dict, index = [0]))
# Out:
# YrSold
#       Var  R Squared     Intercept        Slope   P-value  JB P-value
# 0  YrSold   0.000837  3.654560e+06 -1730.058729  0.269413         0.0

# %%
data_list = list()
for col in data.columns:
    print(col)
    formula = f'SalePrice ~ {col}'
    model = smf.ols(formula = formula, data = data).fit()
    model.summary()
    # Plot the residuals using sm.graphics.plot_regress_exog()
    sm.graphics.plot_regress_exog(model, col)
    # QQ Plot on residuals to see if they are normally distributed.
    sm.graphics.qqplot(model.resid, stats.norm, line = '45', fit = True)
    plt.show()
    results_dict = {'Var': col, 'R Squared': model.rsquared, 'Intercept': model.params[0], 
                    'Slope': model.params[1], 'P-value': model.pvalues[1],
                    'JB P-value': sms.jarque_bera(model.resid)[1]}
    display(pd.DataFrame(results_dict, index = [0]))
    data_list.append(results_dict)
# Out:
# YrSold
#       Var  R Squared     Intercept        Slope   P-value  JB P-value
# 0  YrSold   0.000837  3.654560e+06 -1730.058729  0.269413         0.0
# MoSold
#       Var  R Squared      Intercept        Slope   P-value  JB P-value
# 0  MoSold   0.002156  172295.884154  1364.350502  0.076128         0.0
# Fireplaces
#           Var  R Squared      Intercept         Slope       P-value  \
# 0  Fireplaces   0.218023  145648.490757  57539.831838  6.141487e-80
#
#    JB P-value
# 0         0.0
# TotRmsAbvGrd
#             Var  R Squared     Intercept         Slope        P-value  \
# 0  TotRmsAbvGrd    0.28486  10896.471958  26086.180847  2.772281e-108
#
#    JB P-value
# 0         0.0
# GrLivArea
#          Var  R Squared     Intercept       Slope        P-value  JB P-value
# 0  GrLivArea   0.502149  18569.025856  107.130359  4.518034e-223         0.0
# FullBath
#         Var  R Squared     Intercept         Slope        P-value  JB P-value
# 0  FullBath   0.314344  54388.277324  80848.166787  1.236470e-121         0.0
# YearRemodAdd
#             Var  R Squared     Intercept        Slope       P-value  \
# 0  YearRemodAdd   0.257151 -3.692146e+06  1951.299406  3.164948e-96
#
#    JB P-value
# 0         0.0
# YearBuilt
#          Var  R Squared     Intercept        Slope        P-value  JB P-value
# 0  YearBuilt   0.273422 -2.530308e+06  1375.373468  2.990229e-103         0.0
# OverallCond
#            Var  R Squared      Intercept        Slope   P-value  JB P-value
# 0  OverallCond   0.006062  211909.592494 -5558.115361  0.002912         0.0
# OverallQual
#            Var  R Squared     Intercept         Slope        P-value  \
# 0  OverallQual   0.625652 -96206.079515  45435.802593  2.185675e-313
#
#    JB P-value
# 0         0.0
# LotArea
#        Var  R Squared      Intercept     Slope       P-value  JB P-value
# 0  LotArea   0.069613  158836.151897  2.099972  1.123139e-24         0.0
# SalePrice
#          Var  R Squared     Intercept  Slope  P-value    JB P-value
# 0  SalePrice        1.0  1.182343e-11    1.0      0.0  1.416463e-71

# %%
pd.DataFrame(data_list)
# Out:
#              Var  R Squared     Intercept         Slope        P-value  \
# 0         YrSold   0.000837  3.654560e+06  -1730.058729   2.694132e-01
# 1         MoSold   0.002156  1.722959e+05   1364.350502   7.612758e-02
# 2     Fireplaces   0.218023  1.456485e+05  57539.831838   6.141487e-80
# 3   TotRmsAbvGrd   0.284860  1.089647e+04  26086.180847  2.772281e-108
# 4      GrLivArea   0.502149  1.856903e+04    107.130359  4.518034e-223
# 5       FullBath   0.314344  5.438828e+04  80848.166787  1.236470e-121
# 6   YearRemodAdd   0.257151 -3.692146e+06   1951.299406   3.164948e-96
# 7      YearBuilt   0.273422 -2.530308e+06   1375.373468  2.990229e-103
# 8    OverallCond   0.006062  2.119096e+05  -5558.115361   2.912351e-03
# 9    OverallQual   0.625652 -9.620608e+04  45435.802593  2.185675e-313
# 10       LotArea   0.069613  1.588362e+05      2.099972   1.123139e-24
# 11     SalePrice   1.000000  1.182343e-11      1.000000   0.000000e+00
#
#       JB P-value
# 0   0.000000e+00
# 1   0.000000e+00
# 2   0.000000e+00
# 3   0.000000e+00
# 4   0.000000e+00
# 5   0.000000e+00
# 6   0.000000e+00
# 7   0.000000e+00
# 8   0.000000e+00
# 9   0.000000e+00
# 10  0.000000e+00
# 11  1.416463e-71

# %%
# formula = 'SalePrice ~ YrSold'

# %%
# data.head()
# data.corr()

# %%
# Using a distplot, the residuals can be seen to have a tail on the high side.

# %%
# Store following values in array for each iteration:
# Independent Variable
# r_squared'
# intercept'
# 'slope'
# 'p-value'
# 'normality (JB)'

# %%
# dir(model)

# %%
# print(model.params)
# print(model.pvalues)

# %%
#-1.730059e+03

# %%
#3.654560e+06

# %%
#print(model.rsquared)

# %%
# P-value is less than 0.05, so reject the null H. that the data is normally distributed. 
#sms.jarque_bera(model.resid)[1]

# %%
# results_dict = {'Var': 'YrSold', 'R Squared': model.rsquared,
                #'Intercept': model.params[0], 'Slope': model.params[1], 'P-value': model.pvalues[1], 'JB P-value': sms.jarque_bera(model.resid)[1]}

# %% [markdown]
# Clearly, the results are not very reliable. The best R-Squared is witnessed with `OverallQual`, so in this analysis, this is our best predictor.
#
# ### How can you improve these results?
# 1. Preprocessing
#
# This is where the preprocessing of data comes in. Dealing with outliers, normalizing data, scaling values etc. can help regression analysis get more meaningful results from the given data.
#
# 2. Advanced Analytical Methods
#
# Simple regression is a very basic analysis technique and trying to fit a straight line solution to complex analytical questions may prove to be very inefficient. Later on, you'll explore multiple regression where you can use multiple features **at once** to define a relationship with the outcome. You'll also look at some preprocessing and data simplification techniques and revisit the Ames dataset with an improved toolkit.
#
# ## Level up - Optional
#
# Apply some data wrangling skills that you have learned in the previous section to pre-process the set of independent variables we chose above. You can start off with outliers and think of a way to deal with them. See how it affects the goodness of fit.
#
# ## Summary
#
# In this lab, you applied your skills learned so far on a new data set. You looked at the outcome of your analysis and realized that the data might need some preprocessing to see a clear improvement in the results. You'll pick this back up later on, after learning about more preprocessing techniques and advanced modeling techniques.

# %%
sns.distplot(data['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %%
data_outliers = data[data['SalePrice'] < 400000]
sns.distplot(data_outliers['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %%
data_outliers.corr()
# Out:
#                 YrSold    MoSold  Fireplaces  TotRmsAbvGrd  GrLivArea  \
# YrSold        1.000000 -0.147289   -0.023059     -0.037901  -0.033041
# MoSold       -0.147289  1.000000    0.058332      0.051079   0.071239
# Fireplaces   -0.023059  0.058332    1.000000      0.299425   0.443006
# TotRmsAbvGrd -0.037901  0.051079    0.299425      1.000000   0.817773
# GrLivArea    -0.033041  0.071239    0.443006      0.817773   1.000000
# FullBath     -0.017361  0.063516    0.223909      0.531676   0.611314
# YearRemodAdd  0.036005  0.025758    0.095882      0.165692   0.270570
# YearBuilt    -0.016834  0.017108    0.134569      0.067067   0.176761
# OverallCond   0.046877 -0.004911   -0.020637     -0.051260  -0.076707
# OverallQual  -0.023596  0.084167    0.371830      0.378990   0.554677
# LotArea      -0.016548  0.004345    0.265014      0.167909   0.241918
# SalePrice    -0.029471  0.087163    0.465572      0.480354   0.663579
#
#               FullBath  YearRemodAdd  YearBuilt  OverallCond  OverallQual  \
# YrSold       -0.017361      0.036005  -0.016834     0.046877    -0.023596
# MoSold        0.063516      0.025758   0.017108    -0.004911     0.084167
# Fireplaces    0.223909      0.095882   0.134569    -0.020637     0.371830
# TotRmsAbvGrd  0.531676      0.165692   0.067067    -0.051260     0.378990
# GrLivArea     0.611314      0.270570   0.176761    -0.076707     0.554677
# FullBath      1.000000      0.431427   0.461660    -0.191405     0.532502
# YearRemodAdd  0.431427      1.000000   0.587077     0.081731     0.543809
# YearBuilt     0.461660      0.587077   1.000000    -0.368762     0.570336
# OverallCond  -0.191405      0.081731  -0.368762     1.000000    -0.085339
# OverallQual   0.532502      0.543809   0.570336    -0.085339     1.000000
# LotArea       0.107066      0.000702   0.002450    -0.006082     0.080390
# SalePrice     0.556311      0.538547   0.558338    -0.068317     0.794784
#
#                LotArea  SalePrice
# YrSold       -0.016548  -0.029471
# MoSold        0.004345   0.087163
# Fireplaces    0.265014   0.465572
# TotRmsAbvGrd  0.167909   0.480354
# GrLivArea     0.241918   0.663579
# FullBath      0.107066   0.556311
# YearRemodAdd  0.000702   0.538547
# YearBuilt     0.002450   0.558338
# OverallCond  -0.006082  -0.068317
# OverallQual   0.080390   0.794784
# LotArea       1.000000   0.247922
# SalePrice     0.247922   1.000000

# %%
data.corr()
# Out:
#                 YrSold    MoSold  Fireplaces  TotRmsAbvGrd  GrLivArea  \
# YrSold        1.000000 -0.145721   -0.024096     -0.034516  -0.036526
# MoSold       -0.145721  1.000000    0.046357      0.036907   0.050240
# Fireplaces   -0.024096  0.046357    1.000000      0.326114   0.461679
# TotRmsAbvGrd -0.034516  0.036907    0.326114      1.000000   0.825489
# GrLivArea    -0.036526  0.050240    0.461679      0.825489   1.000000
# FullBath     -0.019669  0.055872    0.243671      0.554784   0.630012
# YearRemodAdd  0.035743  0.021490    0.112581      0.191740   0.287389
# YearBuilt    -0.013618  0.012398    0.147716      0.095589   0.199010
# OverallCond   0.043950 -0.003511   -0.023820     -0.057583  -0.079686
# OverallQual  -0.027347  0.070815    0.396765      0.427452   0.593007
# LotArea      -0.014261  0.001205    0.271364      0.190015   0.263116
# SalePrice    -0.028923  0.046432    0.466929      0.533723   0.708624
#
#               FullBath  YearRemodAdd  YearBuilt  OverallCond  OverallQual  \
# YrSold       -0.019669      0.035743  -0.013618     0.043950    -0.027347
# MoSold        0.055872      0.021490   0.012398    -0.003511     0.070815
# Fireplaces    0.243671      0.112581   0.147716    -0.023820     0.396765
# TotRmsAbvGrd  0.554784      0.191740   0.095589    -0.057583     0.427452
# GrLivArea     0.630012      0.287389   0.199010    -0.079686     0.593007
# FullBath      1.000000      0.439046   0.468271    -0.194149     0.550600
# YearRemodAdd  0.439046      1.000000   0.592855     0.073741     0.550684
# YearBuilt     0.468271      0.592855   1.000000    -0.375983     0.572323
# OverallCond  -0.194149      0.073741  -0.375983     1.000000    -0.091932
# OverallQual   0.550600      0.550684   0.572323    -0.091932     1.000000
# LotArea       0.126031      0.013788   0.014228    -0.005636     0.105806
# SalePrice     0.560664      0.507101   0.522897    -0.077856     0.790982
#
#                LotArea  SalePrice
# YrSold       -0.014261  -0.028923
# MoSold        0.001205   0.046432
# Fireplaces    0.271364   0.466929
# TotRmsAbvGrd  0.190015   0.533723
# GrLivArea     0.263116   0.708624
# FullBath      0.126031   0.560664
# YearRemodAdd  0.013788   0.507101
# YearBuilt     0.014228   0.522897
# OverallCond  -0.005636  -0.077856
# OverallQual   0.105806   0.790982
# LotArea       1.000000   0.263843
# SalePrice     0.263843   1.000000

# %%
sns.distplot(data_outliers['GrLivArea'])
# Out:
# <AxesSubplot:xlabel='GrLivArea'>

# %%
data_outliers = data_outliers[data_outliers['GrLivArea'] < 3000]
sns.distplot(data_outliers['GrLivArea'])
# Out:
# <AxesSubplot:xlabel='GrLivArea'>

# %%
print('GrLivArea')
formula = 'SalePrice ~ GrLivArea'
model = smf.ols(formula = formula, data = data_outliers).fit()
model.summary()
# Plot the residuals using sm.graphics.plot_regress_exog()
sm.graphics.plot_regress_exog(model, 'GrLivArea')
# QQ Plot on residuals to see if they are normally distributed.
sm.graphics.qqplot(model.resid, stats.norm, line = '45', fit = True)
sns.distplot(model.resid)
results_dict = {'Var': 'GrLivArea', 'R Squared': model.rsquared, 'Intercept': model.params[0], 
                'Slope': model.params[1], 'P-value': model.pvalues[1], 'JB P-value': sms.jarque_bera(model.resid)[1]}
display(pd.DataFrame(results_dict, index = [0]))
# Out:
# GrLivArea
#          Var  R Squared    Intercept       Slope        P-value    JB P-value
# 0  GrLivArea   0.482398  26214.16783  100.388363  2.634724e-205  2.760774e-72

# %%
print('GrLivArea')
formula = 'SalePrice ~ GrLivArea'
model = smf.ols(formula = formula, data = data).fit()
model.summary()
# Plot the residuals using sm.graphics.plot_regress_exog()
sm.graphics.plot_regress_exog(model, 'GrLivArea')
# QQ Plot on residuals to see if they are normally distributed.
sm.graphics.qqplot(model.resid, stats.norm, line = '45', fit = True)
sns.distplot(model.resid)
results_dict = {'Var': 'GrLivArea', 'R Squared': model.rsquared, 'Intercept': model.params[0], 
                'Slope': model.params[1], 'P-value': model.pvalues[1], 'JB P-value': sms.jarque_bera(model.resid)[1]}
display(pd.DataFrame(results_dict, index = [0]))
# Out:
# GrLivArea
#          Var  R Squared     Intercept       Slope        P-value  JB P-value
# 0  GrLivArea   0.502149  18569.025856  107.130359  4.518034e-223         0.0
